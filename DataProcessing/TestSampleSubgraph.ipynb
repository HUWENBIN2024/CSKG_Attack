# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import copy
from SampleSubgraph import SampleSubgraph

# %%
G = nx.MultiDiGraph()
for i in range(20):
    G.add_node(i)
    if i!=0:
        for k in range(i):
            G.add_edge(k,i)

# %%
nx.draw_networkx(G)

# %%
SG = SampleSubgraph(G,8,keep_edge_ratio=0.2)
nx.draw_networkx(SG)
